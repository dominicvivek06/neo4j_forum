# %%
#import libs
import pandas as pd
from py2neo.database import Graph
import calendar
import time
# create neo4j graph connection
graph = Graph('bolt://127.0.0.1:7687', auth=(username, password), name="database")

# %%
#test a label
df = pd.DataFrame(graph.run("MATCH (n:Movie) UNWIND keys(n) as property RETURN labels(n) as node,id(n) as node_id , property, n[property] as value").to_table(),columns=['node','node_id','property','value'])

# %%
#print info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   node      113 non-null    object
#  1   node_id   113 non-null    int64
#  2   property  113 non-null    object
#  3   value     113 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.7+ KB

# %%
#print first 5 rows
df.head()
# Out:
#       node  node_id  property                      value
# 0  [Movie]        4     title                 The Matrix
# 1  [Movie]        4   tagline  Welcome to the Real World
# 2  [Movie]        4  released                       1999
# 3  [Movie]        9     title        The Matrix Reloaded
# 4  [Movie]        9   tagline             Free your mind

# %%
# convert object type to string
types =['str','string']
for col in list(df.columns):
    for type in types:
        df[col]=df[col].astype(type)

# %%
# verify datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   node      113 non-null    string
#  1   node_id   113 non-null    string
#  2   property  113 non-null    string
#  3   value     113 non-null    string
# dtypes: string(4)
# memory usage: 3.7 KB

# %%
# remove characters from node column after converting to string
df['node'] = df['node'].str.replace(r"[\']", '')
df['node'] = df['node'].str.replace(r"[\[']", '')
df['node'] = df['node'].str.replace(r"[\]']", '')
df.head()
# Out:
#     node node_id  property                      value
# 0  Movie       4     title                 The Matrix
# 1  Movie       4   tagline  Welcome to the Real World
# 2  Movie       4  released                       1999
# 3  Movie       9     title        The Matrix Reloaded
# 4  Movie       9   tagline             Free your mind

# %%
def get_all_properties(nodename=''):
    # if no node node labels are provided, get all nodes
    ts = str(calendar.timegm(gmt))
    if len(nodename)==0:
        newnode="n"
        filename="all"
    else:
        newnode="n:"+nodename
        filename=nodename
    
    #create a node_property data frame
    node_property_df = pd.DataFrame(graph.run("MATCH ( "+newnode+") UNWIND keys(n) as property RETURN labels(n) as node,id(n) as node_id , property, n[property] as value").to_table(),columns=['node','node_id','property','value'])
    # convert object to string and remove unwanted characters
    types =['str','string']
    for col in list(node_property_df.columns):
        for type in types:
            node_property_df[col]=node_property_df[col].astype(type)
    #better way to do, but currently just using below to remove unwanted characters
    node_property_df['node'] = node_property_df['node'].str.replace(r"[\']", '')
    node_property_df['node'] = node_property_df['node'].str.replace(r"[\[']", '')
    node_property_df['node'] = node_property_df['node'].str.replace(r"[\]']", '')
    # NOTE - movie dataset in neo4j, doesn't have a "id" as a property. So, concentated node-> name and node(id) for building unique index for pivot table.
    node_property_df['node_n_id'] = node_property_df['node']+'_'+node_property_df['node_id']
    #create a pivot dataframe
    pivot = node_property_df.pivot(index='node_n_id',columns='property',values='value')
    # create a sorted pivot table
    sorted_result = pivot.sort_values('node_n_id', ascending=False)
    # both pivot and sorted_result can be one line. for readability, 2 lines of code are used. it can be modified later with the below line
    # retun (node_property_df.pivot(index='node_n_id',columns='property',values='value')).sort_values('node_n_id', ascending=False)
    # save dataframe as a csv file with timestamp
    sorted_result.to_csv(filename+"_"+ts+".csv" )
    #return dataframe
    return sorted_result

# %%
# get all property values for node Person
get_all_properties("Person")
# Out:
# property    born                name
# node_n_id
# Person_99   1930      Clint Eastwood
# Person_98   1930      Richard Harris
# Person_96   1931        Mike Nichols
# Person_94   1954        Zach Grenier
# Person_93   1974      Christian Bale
# ...          ...                 ...
# Person_103  1958               Ice-T
# Person_102  1968          Dina Meyer
# Person_101  1947      Takeshi Kitano
# Person_1    1961  Laurence Fishburne
# Person_0    1967    Carrie-Anne Moss
#
# [133 rows x 2 columns]

# %%
# get all property values for node Movie
get_all_properties("Movie")
# Out:
# property  released                                            tagline  \
# node_n_id
# Movie_97      1992              It's a hell of a thing, killing a man
# Movie_95      1996                                    Come as you are
# Movie_92      2006  Based on the extraordinary true story of one m...
# Movie_9       2003                                     Free your mind
# Movie_87      2000  Pain heals, Chicks dig scars... Glory lasts fo...
# Movie_85      1996  In every life there comes a time when that thi...
# Movie_81      1998  Can two friends sleep together and still love ...
# Movie_78      1990          A story of love, lava and burning desire.
# Movie_73      1993  What if someone you never met, someone you nev...
# Movie_67      1998                At odds in life... in love on-line.
# Movie_62      1999                         First loves last. Forever.
# Movie_56      1998  After life there is more. The end is just the ...
# Movie_52      1997  A comedy from the heart that goes for the throat.
# Movie_46      1986  For some, it's the last real taste of innocenc...
# Movie_4       1999                          Welcome to the Real World
# Movie_37      2000                   The rest of his life begins now.
# Movie_29      1986               I feel the need, the need for speed.
# Movie_162     1992  Once in a lifetime you get a chance to do some...
# Movie_161     2004                     This Holiday Season... Believe
# Movie_159     2007  A stiff drink. A little mascara. A lot of nerv...
# Movie_157     1999  One robot's 200 year journey to become an ordi...
# Movie_154     2003                                               <NA>
# Movie_152     1975            If he's crazy, what does that make you?
# Movie_150     2000      At the edge of the world, his journey begins.
# Movie_15      1992  In the heart of the nation's capital, in a cou...
# Movie_147     1996                    Don't Breathe. Don't Look Back.
# Movie_144     1995                        Houston, we have a problem.
# Movie_141     1992             He didn't want law. He wanted justice.
# Movie_137     2008     400 million people were waiting for the truth.
# Movie_130     1999                   Walk a mile you'll never forget.
# Movie_128     2009       Prepare to enter a secret world of assassins
# Movie_121     2008                                Speed has no limits
# Movie_116     2006                                  Freedom! Forever!
# Movie_111     2006                                    Break The Codes
# Movie_11      1997                          Evil has its winning ways
# Movie_105     2012                            Everything is connected
# Movie_100     1995  The hottest data on earth. In the coolest head...
# Movie_10      2003         Everything that has a beginning has an end
#
# property                             title
# node_n_id
# Movie_97                        Unforgiven
# Movie_95                      The Birdcage
# Movie_92                        RescueDawn
# Movie_9                The Matrix Reloaded
# Movie_87                  The Replacements
# Movie_85                 That Thing You Do
# Movie_81              When Harry Met Sally
# Movie_78            Joe Versus the Volcano
# Movie_73              Sleepless in Seattle
# Movie_67                   You've Got Mail
# Movie_62            Snow Falling on Cedars
# Movie_56              What Dreams May Come
# Movie_52                As Good as It Gets
# Movie_46                       Stand By Me
# Movie_4                         The Matrix
# Movie_37                     Jerry Maguire
# Movie_29                           Top Gun
# Movie_162            A League of Their Own
# Movie_161                The Polar Express
# Movie_159             Charlie Wilson's War
# Movie_157                 Bicentennial Man
# Movie_154           Something's Gotta Give
# Movie_152  One Flew Over the Cuckoo's Nest
# Movie_150                        Cast Away
# Movie_15                    A Few Good Men
# Movie_147                          Twister
# Movie_144                        Apollo 13
# Movie_141                            Hoffa
# Movie_137                      Frost/Nixon
# Movie_130                   The Green Mile
# Movie_128                   Ninja Assassin
# Movie_121                      Speed Racer
# Movie_116                   V for Vendetta
# Movie_111                The Da Vinci Code
# Movie_11              The Devil's Advocate
# Movie_105                      Cloud Atlas
# Movie_100                  Johnny Mnemonic
# Movie_10            The Matrix Revolutions

# %%
# get all property values for all the nodes
get_all_properties()
# Out:
# property   born            name released  \
# node_n_id
# Person_99  1930  Clint Eastwood     <NA>
# Person_98  1930  Richard Harris     <NA>
# Person_96  1931    Mike Nichols     <NA>
# Person_94  1954    Zach Grenier     <NA>
# Person_93  1974  Christian Bale     <NA>
# ...         ...             ...      ...
# Movie_111  <NA>            <NA>     2006
# Movie_11   <NA>            <NA>     1997
# Movie_105  <NA>            <NA>     2012
# Movie_100  <NA>            <NA>     1995
# Movie_10   <NA>            <NA>     2003
#
# property                                             tagline  \
# node_n_id
# Person_99                                               <NA>
# Person_98                                               <NA>
# Person_96                                               <NA>
# Person_94                                               <NA>
# Person_93                                               <NA>
# ...                                                      ...
# Movie_111                                    Break The Codes
# Movie_11                           Evil has its winning ways
# Movie_105                            Everything is connected
# Movie_100  The hottest data on earth. In the coolest head...
# Movie_10          Everything that has a beginning has an end
#
# property                    title
# node_n_id
# Person_99                    <NA>
# Person_98                    <NA>
# Person_96                    <NA>
# Person_94                    <NA>
# Person_93                    <NA>
# ...                           ...
# Movie_111       The Da Vinci Code
# Movie_11     The Devil's Advocate
# Movie_105             Cloud Atlas
# Movie_100         Johnny Mnemonic
# Movie_10   The Matrix Revolutions
#
# [171 rows x 5 columns]
